# %%
import os
os.chdir('../src')

from local_score import LocalMetric
import matplotlib.pyplot as plt
import pickle
from sklearn.model_selection import train_test_split

# %%
from keras.datasets import fashion_mnist

(X_train_full, y_train_full), (X_test_full, y_test_full) = fashion_mnist.load_data()

# train_images, _, train_labels, _ = train_test_split(X_train_full, y_train_full, train_size=0.1, random_state=42)
# test_images, _, test_labels, _ = train_test_split(X_test_full, y_test_full, train_size=0.1, random_state=42)

# %%
X_train = X_train_full.reshape(X_train_full.shape[0], -1)
X_test = X_test_full.reshape(X_test_full.shape[0], -1)

# %% [markdown]
# ### K-Means

# %% [markdown]
# Global

# %%
with open('../stored_results/kmeans/global/umap/data/umap_clean.pkl', 'rb') as f:
    umap_clean = pickle.load(f)

umap_metrics_kmeans_global = LocalMetric()
umap_metrics_kmeans_global.calculate_knn_gain_and_dr_quality(
        X_lds= umap_clean,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap", "clean"),
    )
# Out:
# Calculating d_hd
# umap clean

# %%
with open('../stored_results/kmeans/global/umap/data/umap_global_100.pkl', 'rb') as f:
    umap_global_100 = pickle.load(f)

umap_metrics_kmeans_global.calculate_knn_gain_and_dr_quality(
        X_lds= umap_global_100,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + kmeans global", "100 centroids"),
    )
# Out:
# Calculating d_hd
# umap + kmeans global 100 centroids

# %%
with open('../stored_results/kmeans/global/umap/data/umap_global_500.pkl', 'rb') as f:
    umap_global_500= pickle.load(f)

umap_metrics_kmeans_global.calculate_knn_gain_and_dr_quality(
        X_lds= umap_global_500,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + kmeans global", "500 centroids"),
    )
# Out:
# Calculating d_hd
# umap + kmeans global 500 centroids

# %%
with open('../stored_results/kmeans/global/umap/data/umap_global_1000.pkl', 'rb') as f:
    umap_global_1000 = pickle.load(f)

umap_metrics_kmeans_global.calculate_knn_gain_and_dr_quality(
        X_lds= umap_global_1000,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + kmeans global", "1000 centroids"),
    )
# Out:
# Calculating d_hd
# umap + kmeans global 1000 centroids

# %%
umap_metrics_kmeans_global.visualize()
plt.savefig('../stored_results/kmeans/global/umap/images/kmeans_global_umap.png')
# Out:
# Finished.

# %% [markdown]
# Local

# %%
with open('../stored_results/kmeans/local/umap/data/umap_clean.pkl', 'rb') as f:
    umap_clean = pickle.load(f)

umap_metrics_kmeans_local = LocalMetric()
umap_metrics_kmeans_local.calculate_knn_gain_and_dr_quality(
        X_lds= umap_clean,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap", "clean"),
    )
# Out:
# Calculating d_hd
# umap clean

# %%
with open('../stored_results/kmeans/local/umap/data/umap_local_10.pkl', 'rb') as f:
    umap_local10 = pickle.load(f)

umap_metrics_kmeans_local.calculate_knn_gain_and_dr_quality(
        X_lds= umap_local10,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + kmeans local", "10 centroids"),
    )
# Out:
# Calculating d_hd
# umap + kmeans local 10 centroids

# %%
with open('../stored_results/kmeans/local/umap/data/umap_local_50.pkl', 'rb') as f:
    umap_local50 = pickle.load(f)

umap_metrics_kmeans_local.calculate_knn_gain_and_dr_quality(
        X_lds= umap_local50,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + kmeans local", "50 centroids"),
    )
# Out:
# Calculating d_hd
# umap + kmeans local 50 centroids

# %%
with open('../stored_results/kmeans/local/umap/data/umap_local_100.pkl', 'rb') as f:
    umap_local100 = pickle.load(f)

umap_metrics_kmeans_local.calculate_knn_gain_and_dr_quality(
        X_lds= umap_local100,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + kmeans local", "100 centroids"),
    )
# Out:
# Calculating d_hd
# umap + kmeans local 100 centroids

# %%
umap_metrics_kmeans_local.visualize()
plt.savefig('../stored_results/kmeans/local/umap/images/kmeans_local_umap.png')
# Out:
# Finished.

# %% [markdown]
# ### Agglomerative

# %% [markdown]
# Global

# %%
with open('../stored_results/agglomerative/global/umap/data/umap_clean.pkl', 'rb') as f:
    umap_clean = pickle.load(f)

umap_metrics_agglomerative_global = LocalMetric()
umap_metrics_agglomerative_global.calculate_knn_gain_and_dr_quality(
        X_lds= umap_clean,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap", "clean"),
    )
# Out:
# Calculating d_hd
# umap clean

# %%
with open('../stored_results/agglomerative/global/umap/data/umap_global_100.pkl', 'rb') as f:
    umap_global_100ag = pickle.load(f)

umap_metrics_agglomerative_global.calculate_knn_gain_and_dr_quality(
        X_lds= umap_global_100ag,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + agglomerative global", "100 centroids"),
    )
# Out:
# Calculating d_hd
# umap + agglomerative global 100 centroids

# %%
with open('../stored_results/agglomerative/global/umap/data/umap_global_500.pkl', 'rb') as f:
    umap_global_500ag = pickle.load(f)

umap_metrics_agglomerative_global.calculate_knn_gain_and_dr_quality(
        X_lds= umap_global_500ag,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + agglomerative global", "500 centroids"),
    )
# Out:
# Calculating d_hd
# umap + agglomerative global 500 centroids

# %%
with open('../stored_results/agglomerative/global/umap/data/umap_global_1000.pkl', 'rb') as f:
    umap_global_1000ag = pickle.load(f)

umap_metrics_agglomerative_global.calculate_knn_gain_and_dr_quality(
        X_lds= umap_global_1000ag,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + agglomerative global", "1000 centroids"),
    )
# Out:
# Calculating d_hd
# umap + agglomerative global 1000 centroids

# %%
umap_metrics_agglomerative_global.visualize()
plt.savefig('../stored_results/agglomerative/global/umap/images/agglomerative_global_umap.png')
# Out:
# Finished.

# %% [markdown]
# Local

# %%
with open('../stored_results/agglomerative/local/umap/data/umap_clean.pkl', 'rb') as f:
    umap_clean = pickle.load(f)

umap_metrics_agglomerative_local = LocalMetric()
umap_metrics_agglomerative_local.calculate_knn_gain_and_dr_quality(
        X_lds= umap_clean,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap", "clean"),
    )
# Out:
# Calculating d_hd
# umap clean

# %%
with open('../stored_results/agglomerative/local/umap/data/umap_local_10.pkl', 'rb') as f:
    umap_local_10ag = pickle.load(f)

umap_metrics_agglomerative_local.calculate_knn_gain_and_dr_quality(
        X_lds= umap_local_10ag,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + agglomerative local", "10 centroids"),
    )
# Out:
# Calculating d_hd
# umap + agglomerative local 10 centroids

# %%
with open('../stored_results/agglomerative/local/umap/data/umap_local_50.pkl', 'rb') as f:
    umap_local_50ag = pickle.load(f)

umap_metrics_agglomerative_local.calculate_knn_gain_and_dr_quality(
        X_lds= umap_local_50ag,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + agglomerative local", "50 centroids"),
    )
# Out:
# Calculating d_hd
# umap + agglomerative local 50 centroids

# %%
with open('../stored_results/agglomerative/local/umap/data/umap_local_100.pkl', 'rb') as f:
    umap_local_100ag = pickle.load(f)

umap_metrics_agglomerative_local.calculate_knn_gain_and_dr_quality(
        X_lds= umap_local_100ag,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + agglomerative local", "100 centroids"),
    )
# Out:
# Calculating d_hd
# umap + agglomerative local 100 centroids

# %%
umap_metrics_agglomerative_local.visualize()
plt.savefig('../stored_results/agglomerative/local/umap/images/agglomerative_local_umap.png')
# Out:
# Finished.

# %% [markdown]
# ### DBSCAN

# %% [markdown]
# Global + Local

# %%
with open('../stored_results/dbscan/global/umap/data/umap_clean.pkl', 'rb') as f:
    umap_clean = pickle.load(f)

umap_metrics_dbscan = LocalMetric()
umap_metrics_dbscan.calculate_knn_gain_and_dr_quality(
        X_lds= umap_clean,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap", "clean"),
    )
# Out:
# Calculating d_hd
# umap clean

# %%
with open('../stored_results/dbscan/global/umap/data/umap_global_10.pkl', 'rb') as f:
    umap_global_10dbscan = pickle.load(f)

umap_metrics_dbscan.calculate_knn_gain_and_dr_quality(
        X_lds= umap_global_10dbscan,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + dbscan global", "10 centroids"),
    )
# Out:
# Calculating d_hd
# umap + dbscan global 10 centroids

# %%
with open('../stored_results/dbscan/local/umap/data/umap_local_10.pkl', 'rb') as f:
    umap_local_10dbscan = pickle.load(f)

umap_metrics_dbscan.calculate_knn_gain_and_dr_quality(
        X_lds= umap_local_10dbscan,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + dbscan local", "10 centroids"),
    )
# Out:
# Calculating d_hd
# umap + dbscan local 10 centroids

# %%
umap_metrics_dbscan.visualize()
plt.savefig('../stored_results/dbscan/global/umap/images/dbscan_global_umap.png')
plt.savefig('../stored_results/dbscan/local/umap/images/dbscan_local_umap.png')
# Out:
# Finished.

# %% [markdown]
# ### Jarvis-Patrick

# %% [markdown]
# Global

# %%
with open('../stored_results/jp/global/umap/data/umap_clean.pkl', 'rb') as f:
    umap_clean = pickle.load(f)

umap_metrics_jp_global = LocalMetric()
umap_metrics_jp_global.calculate_knn_gain_and_dr_quality(
        X_lds= umap_clean,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap", "clean"),
    )
# Out:
# Calculating d_hd
# umap clean

# %%
with open('../stored_results/jp/global/umap/data/umap_global_91.pkl', 'rb') as f:
    umap_jp_global91 = pickle.load(f)

umap_metrics_jp_global.calculate_knn_gain_and_dr_quality(
        X_lds= umap_jp_global91,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + jarvis-patrick global", "91 centroids"),
    )
# Out:
# Calculating d_hd
# umap + jarvis-patrick global 91 centroids

# %%
with open('../stored_results/jp/global/umap/data/umap_global_507.pkl', 'rb') as f:
    umap_jp_global507 = pickle.load(f)

umap_metrics_jp_global.calculate_knn_gain_and_dr_quality(
        X_lds= umap_jp_global507,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + jarvis-patrick global", "507 centroids"),
    )
# Out:
# Calculating d_hd
# umap + jarvis-patrick global 507 centroids

# %%
with open('../stored_results/jp/global/umap/data/umap_global_1003.pkl', 'rb') as f:
    umap_jp_global1003 = pickle.load(f)

umap_metrics_jp_global.calculate_knn_gain_and_dr_quality(
        X_lds= umap_jp_global1003,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + jarvis-patrick global", "1003 centroids"),
    )
# Out:
# Calculating d_hd
# umap + jarvis-patrick global 1003 centroids

# %%
umap_metrics_jp_global.visualize()
plt.savefig('../stored_results/jp/global/umap/images/jp_global_umap.png')
# Out:
# Finished.

# %% [markdown]
# Local

# %%
with open('../stored_results/jp/local/umap/data/umap_clean.pkl', 'rb') as f:
    umap_clean = pickle.load(f)

umap_metrics_jp_local = LocalMetric()
umap_metrics_jp_local.calculate_knn_gain_and_dr_quality(
        X_lds= umap_clean,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap", "clean"),
    )
# Out:
# Calculating d_hd
# umap clean

# %%
with open('../stored_results/jp/local/umap/data/umap_local_109.pkl', 'rb') as f:
    umap_local_109 = pickle.load(f)

umap_metrics_jp_local.calculate_knn_gain_and_dr_quality(
        X_lds= umap_local_109,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + jarvis-patrick local", "109 centroids"),
    )
# Out:
# Calculating d_hd
# umap + jarvis-patrick local 109 centroids

# %%
with open('../stored_results/jp/local/umap/data/umap_local_504.pkl', 'rb') as f:
    umap_local_504 = pickle.load(f)

umap_metrics_jp_local.calculate_knn_gain_and_dr_quality(
        X_lds= umap_local_504,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + jarvis-patrick local", "504 centroids"),
    )
# Out:
# Calculating d_hd
# umap + jarvis-patrick local 504 centroids

# %%
with open('../stored_results/jp/local/umap/data/umap_local_991.pkl', 'rb') as f:
    umap_local_991 = pickle.load(f)

umap_metrics_jp_local.calculate_knn_gain_and_dr_quality(
        X_lds= umap_local_991,
        X_hds=X_test,
        labels=y_test_full,
        method_name="{} {}".format("umap + jarvis-patrick local", "991 centroids"),
    )
# Out:
# Calculating d_hd
# umap + jarvis-patrick local 991 centroids

# %%
umap_metrics_jp_local.visualize()
plt.savefig('../stored_results/jp/local/umap/images/jp_local_umap.png')
# Out:
# Finished.
